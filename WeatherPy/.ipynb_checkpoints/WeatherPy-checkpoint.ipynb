# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\jason\anaconda3\envs\pythondata\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kdtree>=0.12 in c:\users\jason\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
import time
import json
import scipy.stats as st

#import api key from configs.py file
from configs import api_key

#city data based on lat. and long.
from citipy import citipy

#output file (csv)
output_data_file = "output_data/cities.csv"

#Range of latitudes and logitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

#np.random.seed(1)
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
#set up dataframe and create empty columns for the data to be entered into
cities_df = pd.DataFrame({"City": cities})
cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Humidity"] = ""
cities_df["Cloudiness"] = ""
cities_df["Wind Speed"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""

#base url ready for the city name to be added to the end
base_url = f'http://api.openweathermap.org/data/2.5/weather?appid={api_key}&q='

#starting data retrieval
print("Beginning Data Retrieval")
print("-----------------------------")
#go through cities_df by city name and start entering in the info from the API
for index, row in cities_df.iterrows():
    #get city from df 
    city_name = row["City"]
    #assemble url and make api call
    response = requests.get(base_url + city_name).json()
    
    #try to fill in the df, else print skipping
    try:
        cities_df.loc[index, 'Lat'] = response['coord']['lat']
        cities_df.loc[index, 'Lng'] = response['coord']['lon']
        cities_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        cities_df.loc[index, 'Humidity'] = response['main']['humidity']
        cities_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        cities_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        cities_df.loc[index, 'Country'] = response['sys']['country']
        cities_df.loc[index, 'Date'] = response['dt']
        print(f'Processing record {index} | {city_name}')
    except (KeyError, IndexError):
        print("City not found. Skipping...")
        #delete that row from df
        cities_df = cities_df.drop([index])

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")

#convert Max temp from Kelvin to Fahrenheit and Wind Speed from m/s to mph
cities_df["Max Temp"] = cities_df["Max Temp"] * 1.8 - 459.67
cities_df["Wind Speed"] = cities_df["Wind Speed"] / 0.44704
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 0 | buraydah
# Processing record 1 | punta arenas
# Processing record 2 | port alfred
# Processing record 3 | ust-kulom
# Processing record 4 | atuona
# Processing record 5 | tasiilaq
# Processing record 6 | ushuaia
# Processing record 7 | puerto colombia
# Processing record 8 | tezu
# Processing record 9 | xunchang
# Processing record 10 | kavieng
# Processing record 11 | jamestown
# Processing record 12 | kavaratti
# Processing record 13 | victoria
# Processing record 14 | busselton
# Processing record 15 | siilinjarvi
# Processing record 16 | castro
# Processing record 17 | san patricio
# Processing record 18 | avarua
# Processing record 19 | kindu
# Processing record 20 | saint-philippe
# Processing record 21 | carnarvon
# Processing record 22 | rikitea
# City not found. Skipping...
# Processing record 24 | bredasdorp
# Processing record 25 | gorom-gorom
# Processing record 26 | broome
# Processing record 27 | airai
# Processing record 28 | jalu
# Processing record 29 | jabinyanah
# Processing record 30 | ternate
# Processing record 31 | mehamn
# Processing record 32 | upernavik
# Processing record 33 | havre-saint-pierre
# Processing record 34 | lagoa
# Processing record 35 | khatanga
# Processing record 36 | kaeo
# Processing record 37 | rahuri
# Processing record 38 | mataura
# Processing record 39 | hermanus
# Processing record 40 | vaini
# Processing record 41 | hobart
# Processing record 42 | bubaque
# Processing record 43 | barrow
# Processing record 44 | butaritari
# Processing record 45 | dikson
# Processing record 46 | umm bab
# City not found. Skipping...
# Processing record 48 | los llanos de aridane
# Processing record 49 | maniitsoq
# Processing record 50 | hasaki
# Processing record 51 | lichinga
# Processing record 52 | tiksi
# Processing record 53 | thompson
# Processing record 54 | salalah
# Processing record 55 | aklavik
# Processing record 56 | kapaa
# Processing record 57 | cidreira
# City not found. Skipping...
# Processing record 59 | provideniya
# Processing record 60 | saldanha
# Processing record 61 | mahebourg
# Processing record 62 | qaanaaq
# Processing record 63 | kodiak
# Processing record 64 | hilo
# Processing record 65 | luderitz
# Processing record 66 | beringovskiy
# Processing record 67 | hami
# Processing record 68 | cape town
# City not found. Skipping...
# Processing record 70 | banting
# City not found. Skipping...
# City not found. Skipping...
# Processing record 73 | waingapu
# City not found. Skipping...
# Processing record 75 | plettenberg bay
# City not found. Skipping...
# Processing record 77 | clyde river
# Processing record 78 | zheleznodorozhnyy
# Processing record 79 | bluff
# Processing record 80 | sembakung
# City not found. Skipping...
# Processing record 82 | pangnirtung
# Processing record 83 | warrington
# Processing record 84 | ancud
# Processing record 85 | guerrero negro
# Processing record 86 | banda aceh
# Processing record 87 | nikolskoye
# Processing record 88 | paranaiba
# Processing record 89 | kaohsiung
# Processing record 90 | gimli
# Processing record 91 | inhambane
# Processing record 92 | hirara
# Processing record 93 | tuktoyaktuk
# Processing record 94 | luang prabang
# Processing record 95 | mar del plata
# Processing record 96 | torbay
# Processing record 97 | sobolevo
# Processing record 98 | yenangyaung
# Processing record 99 | kaitangata
# Processing record 100 | isangel
# Processing record 101 | toguchin
# Processing record 102 | aguia branca
# Processing record 103 | padang
# Processing record 104 | aranos
# Processing record 105 | kamenka
# Processing record 106 | nanortalik
# Processing record 107 | sao filipe
# City not found. Skipping...
# Processing record 109 | bandar
# Processing record 110 | talnakh
# Processing record 111 | katsuura
# Processing record 112 | bandarbeyla
# Processing record 113 | hithadhoo
# City not found. Skipping...
# Processing record 115 | paamiut
# Processing record 116 | zyryanskoye
# Processing record 117 | yellowknife
# Processing record 118 | klaksvik
# Processing record 119 | soavinandriana
# Processing record 120 | palmer
# Processing record 121 | sainte-suzanne
# Processing record 122 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing record 125 | souillac
# Processing record 126 | pacific grove
# Processing record 127 | pisco
# Processing record 128 | severodvinsk
# Processing record 129 | voh
# Processing record 130 | port blair
# Processing record 131 | tupik
# Processing record 132 | yuci
# Processing record 133 | grand gaube
# Processing record 134 | punta gorda
# Processing record 135 | sitka
# Processing record 136 | vao
# Processing record 137 | gunjur
# Processing record 138 | ribeira grande
# Processing record 139 | moussoro
# Processing record 140 | los altos
# Processing record 141 | nuuk
# Processing record 142 | mangrol
# Processing record 143 | port hedland
# Processing record 144 | craig
# Processing record 145 | derzhavinsk
# Processing record 146 | sambava
# City not found. Skipping...
# Processing record 148 | nemuro
# Processing record 149 | karratha
# Processing record 150 | salt
# City not found. Skipping...
# Processing record 152 | baruun-urt
# Processing record 153 | taguatinga
# City not found. Skipping...
# Processing record 155 | la ciotat
# Processing record 156 | bria
# Processing record 157 | faanui
# Processing record 158 | constitucion
# Processing record 159 | mount isa
# Processing record 160 | bandipur
# Processing record 161 | yumaguzino
# Processing record 162 | knysna
# Processing record 163 | arraial do cabo
# Processing record 164 | wertheim
# Processing record 165 | vanavara
# Processing record 166 | vanimo
# Processing record 167 | fairbanks
# Processing record 168 | sao joao da barra
# Processing record 169 | chokurdakh
# Processing record 170 | iqaluit
# Processing record 171 | chumikan
# Processing record 172 | san-pedro
# Processing record 173 | berlevag
# Processing record 174 | tbilisskaya
# Processing record 175 | kislovodsk
# Processing record 176 | jacksonville
# Processing record 177 | oussouye
# Processing record 178 | chernyshevskiy
# Processing record 179 | sao miguel do araguaia
# Processing record 180 | geraldton
# Processing record 181 | ostrovnoy
# Processing record 182 | omsukchan
# Processing record 183 | havoysund
# City not found. Skipping...
# Processing record 185 | saint george
# Processing record 186 | bilibino
# Processing record 187 | tuatapere
# Processing record 188 | yabrud
# Processing record 189 | bethel
# Processing record 190 | bereda
# City not found. Skipping...
# Processing record 192 | nome
# Processing record 193 | albany
# Processing record 194 | fuente de oro
# Processing record 195 | rio grande
# Processing record 196 | lebu
# Processing record 197 | barry
# City not found. Skipping...
# Processing record 199 | gallup
# Processing record 200 | balkanabat
# Processing record 201 | vilcun
# Processing record 202 | hambantota
# Processing record 203 | ilulissat
# Processing record 204 | swellendam
# Processing record 205 | parana
# Processing record 206 | east london
# Processing record 207 | meulaboh
# Processing record 208 | shelburne
# Processing record 209 | fortuna
# Processing record 210 | nova olimpia
# City not found. Skipping...
# Processing record 212 | vila franca do campo
# Processing record 213 | petropavlovsk-kamchatskiy
# Processing record 214 | san jose de buan
# Processing record 215 | saint-joseph
# Processing record 216 | beckley
# Processing record 217 | berdigestyakh
# City not found. Skipping...
# Processing record 219 | longyearbyen
# City not found. Skipping...
# Processing record 221 | doha
# Processing record 222 | hailey
# Processing record 223 | san cristobal
# Processing record 224 | puerto ayora
# Processing record 225 | mikropolis
# Processing record 226 | asekeyevo
# Processing record 227 | luanda
# Processing record 228 | coihaique
# Processing record 229 | caravelas
# Processing record 230 | tourlaville
# Processing record 231 | cleethorpes
# Processing record 232 | sombrerete
# Processing record 233 | alta floresta
# Processing record 234 | roma
# Processing record 235 | kudahuvadhoo
# Processing record 236 | fukue
# Processing record 237 | lexington
# Processing record 238 | tilichiki
# Processing record 239 | la rioja
# City not found. Skipping...
# Processing record 241 | saskylakh
# Processing record 242 | new norfolk
# Processing record 243 | baykit
# Processing record 244 | kulunda
# City not found. Skipping...
# Processing record 246 | yanam
# Processing record 247 | cabo san lucas
# Processing record 248 | nadym
# Processing record 249 | istok
# Processing record 250 | xai-xai
# Processing record 251 | izhma
# Processing record 252 | romitan
# Processing record 253 | encruzilhada do sul
# Processing record 254 | rio gallegos
# Processing record 255 | orbetello
# Processing record 256 | port moresby
# City not found. Skipping...
# City not found. Skipping...
# Processing record 259 | fort saint james
# Processing record 260 | el ocotito
# Processing record 261 | asyut
# City not found. Skipping...
# Processing record 263 | flin flon
# Processing record 264 | waddan
# Processing record 265 | sabha
# Processing record 266 | taksimo
# Processing record 267 | vardo
# Processing record 268 | kahului
# Processing record 269 | tignere
# City not found. Skipping...
# Processing record 271 | gamboula
# Processing record 272 | haines junction
# Processing record 273 | georgetown
# Processing record 274 | grand baie
# Processing record 275 | krasnoarmeysk
# Processing record 276 | carballo
# Processing record 277 | taoudenni
# Processing record 278 | onverwacht
# Processing record 279 | vila velha
# City not found. Skipping...
# City not found. Skipping...
# Processing record 282 | vilhena
# Processing record 283 | shenzhen
# Processing record 284 | sibolga
# Processing record 285 | prince george
# Processing record 286 | esperance
# Processing record 287 | vestmannaeyjar
# Processing record 288 | camopi
# Processing record 289 | menzelinsk
# Processing record 290 | mount gambier
# Processing record 291 | sovetskiy
# Processing record 292 | caconda
# Processing record 293 | half moon bay
# Processing record 294 | chapais
# Processing record 295 | concordia
# Processing record 296 | kardla
# Processing record 297 | ewa beach
# Processing record 298 | bud
# Processing record 299 | gorin
# Processing record 300 | kousseri
# Processing record 301 | tonstad
# Processing record 302 | husavik
# Processing record 303 | harper
# Processing record 304 | gravdal
# Processing record 305 | burhanpur
# Processing record 306 | yar-sale
# Processing record 307 | bull savanna
# Processing record 308 | pevek
# Processing record 309 | basay
# Processing record 310 | port lincoln
# Processing record 311 | ponta do sol
# Processing record 312 | saint-augustin
# Processing record 313 | dum duma
# Processing record 314 | carutapera
# City not found. Skipping...
# Processing record 316 | sarangani
# Processing record 317 | carhuamayo
# City not found. Skipping...
# Processing record 319 | jonesboro
# Processing record 320 | pandan
# Processing record 321 | kruisfontein
# Processing record 322 | novaya igirma
# Processing record 323 | necochea
# Processing record 324 | domnesti
# Processing record 325 | lakewood
# Processing record 326 | mayo
# Processing record 327 | sarangarh
# Processing record 328 | bathsheba
# Processing record 329 | bianzhuang
# Processing record 330 | panzhihua
# Processing record 331 | kutum
# Processing record 332 | taganak
# Processing record 333 | baculin
# Processing record 334 | walvis bay
# Processing record 335 | dasoguz
# Processing record 336 | miramar
# Processing record 337 | yerbogachen
# Processing record 338 | tanout
# Processing record 339 | margate
# Processing record 340 | bambous virieux
# Processing record 341 | la ronge
# Processing record 342 | olafsvik
# Processing record 343 | isla vista
# City not found. Skipping...
# Processing record 345 | invermere
# Processing record 346 | puerto escondido
# Processing record 347 | palana
# City not found. Skipping...
# City not found. Skipping...
# Processing record 350 | northam
# Processing record 351 | tortoli
# Processing record 352 | mazagao
# Processing record 353 | zhadovka
# Processing record 354 | praia da vitoria
# Processing record 355 | biak
# Processing record 356 | san carlos
# Processing record 357 | dicabisagan
# Processing record 358 | port hardy
# Processing record 359 | riyadh
# Processing record 360 | ronne
# Processing record 361 | turangi
# Processing record 362 | hammerfest
# Processing record 363 | mezen
# Processing record 364 | dudinka
# Processing record 365 | aykhal
# Processing record 366 | chalus
# Processing record 367 | ondjiva
# Processing record 368 | faya
# Processing record 369 | keti bandar
# Processing record 370 | stephenville
# Processing record 371 | the valley
# Processing record 372 | ilici
# Processing record 373 | pinega
# Processing record 374 | coahuayana
# Processing record 375 | gamba
# Processing record 376 | gofitskoye
# Processing record 377 | datong
# Processing record 378 | mae hong son
# Processing record 379 | cockburn town
# Processing record 380 | idlib
# Processing record 381 | norman wells
# Processing record 382 | lasa
# Processing record 383 | waipawa
# Processing record 384 | quatre cocos
# Processing record 385 | mahibadhoo
# Processing record 386 | umm lajj
# Processing record 387 | aguilas
# Processing record 388 | monywa
# Processing record 389 | uspenskoye
# Processing record 390 | arriaga
# Processing record 391 | jalalpur pirwala
# Processing record 392 | saint anthony
# Processing record 393 | pushkinskiye gory
# Processing record 394 | chuy
# City not found. Skipping...
# Processing record 396 | port elizabeth
# Processing record 397 | pervomayskoye
# Processing record 398 | luan
# Processing record 399 | sinnamary
# Processing record 400 | maceio
# Processing record 401 | lompoc
# Processing record 402 | lata
# Processing record 403 | birao
# Processing record 404 | rantoul
# Processing record 405 | turukhansk
# Processing record 406 | sandviken
# Processing record 407 | great yarmouth
# Processing record 408 | grindavik
# Processing record 409 | fort nelson
# Processing record 410 | totness
# Processing record 411 | boizenburg
# Processing record 412 | cayenne
# Processing record 413 | praia
# Processing record 414 | zambezi
# Processing record 415 | khorinsk
# Processing record 416 | eureka
# Processing record 417 | hervey bay
# Processing record 418 | sajanan
# Processing record 419 | idaho falls
# City not found. Skipping...
# Processing record 421 | harrismith
# Processing record 422 | toppenish
# City not found. Skipping...
# Processing record 424 | manado
# Processing record 425 | inirida
# Processing record 426 | manga
# Processing record 427 | sola
# City not found. Skipping...
# City not found. Skipping...
# Processing record 430 | sur
# Processing record 431 | togur
# Processing record 432 | adeje
# City not found. Skipping...
# Processing record 434 | mango
# Processing record 435 | tanay
# Processing record 436 | daru
# Processing record 437 | belyy yar
# Processing record 438 | chiredzi
# Processing record 439 | mandurah
# Processing record 440 | bogorodskoye
# Processing record 441 | codrington
# Processing record 442 | santa luzia
# Processing record 443 | zelenogorskiy
# Processing record 444 | pontes e lacerda
# Processing record 445 | mathathane
# Processing record 446 | sedona
# Processing record 447 | waikuku
# Processing record 448 | den helder
# Processing record 449 | krasnoselkup
# Processing record 450 | narsaq
# Processing record 451 | mitsamiouli
# Processing record 452 | bontang
# Processing record 453 | vaitape
# Processing record 454 | virginia beach
# City not found. Skipping...
# Processing record 456 | honningsvag
# Processing record 457 | lavrentiya
# Processing record 458 | saraland
# Processing record 459 | nedryhayliv
# Processing record 460 | melo
# Processing record 461 | sao gabriel da cachoeira
# Processing record 462 | ayagoz
# Processing record 463 | koygorodok
# Processing record 464 | oxford
# Processing record 465 | carson city
# Processing record 466 | komsomolskiy
# Processing record 467 | nouadhibou
# Processing record 468 | dalvik
# City not found. Skipping...
# Processing record 470 | bengkulu
# Processing record 471 | gezing
# City not found. Skipping...
# Processing record 473 | wundanyi
# Processing record 474 | sarkand
# Processing record 475 | kununurra
# Processing record 476 | yenagoa
# Processing record 477 | cardston
# Processing record 478 | mabaruma
# Processing record 479 | tura
# Processing record 480 | lorengau
# Processing record 481 | svetlogorsk
# Processing record 482 | erenhot
# Processing record 483 | sukhumi
# City not found. Skipping...
# Processing record 485 | gidole
# City not found. Skipping...
# Processing record 487 | linxia
# Processing record 488 | leh
# Processing record 489 | helena
# Processing record 490 | timra
# Processing record 491 | susuman
# Processing record 492 | ahipara
# Processing record 493 | kozulka
# Processing record 494 | takoradi
# Processing record 495 | marzuq
# Processing record 496 | casablanca
# Processing record 497 | urumqi
# Processing record 498 | anadyr
# Processing record 499 | kondinskoye
# Processing record 500 | bose
# Processing record 501 | intipuca
# Processing record 502 | mossoro
# Processing record 503 | byron bay
# Processing record 504 | severo-kurilsk
# Processing record 505 | bluefields
# Processing record 506 | darnah
# Processing record 507 | thinadhoo
# Processing record 508 | atambua
# Processing record 509 | ormara
# Processing record 510 | christchurch
# Processing record 511 | surt
# Processing record 512 | mpika
# Processing record 513 | ayan
# Processing record 514 | peleduy
# Processing record 515 | shintomi
# Processing record 516 | galle
# Processing record 517 | pirgos
# Processing record 518 | gushikawa
# Processing record 519 | shimoda
# Processing record 520 | sidney
# Processing record 521 | viedma
# Processing record 522 | seoul
# Processing record 523 | staryy nadym
# Processing record 524 | goderich
# Processing record 525 | hojai
# Processing record 526 | korla
# Processing record 527 | ileza
# Processing record 528 | labrea
# City not found. Skipping...
# Processing record 530 | pinos
# Processing record 531 | wanaka
# Processing record 532 | kieta
# Processing record 533 | richards bay
# Processing record 534 | tarnogskiy gorodok
# Processing record 535 | genhe
# Processing record 536 | pangai
# Processing record 537 | khorixas
# Processing record 538 | olinda
# Processing record 539 | prachuap khiri khan
# Processing record 540 | nybro
# Processing record 541 | lerwick
# Processing record 542 | zmeinogorsk
# Processing record 543 | hofn
# Processing record 544 | pitimbu
# Processing record 545 | gashua
# Processing record 546 | suba
# Processing record 547 | kalmunai
# Processing record 548 | aquiraz
# Processing record 549 | guasdualito
# Processing record 550 | zhigansk
# Processing record 551 | ixtapa
# Processing record 552 | tigre
# Processing record 553 | kapit
# Processing record 554 | portland
# Processing record 555 | jardim
# Processing record 556 | cabedelo
# Processing record 557 | araouane
# Processing record 558 | muslyumovo
# Processing record 559 | ballina
# Processing record 560 | coromandel
# Processing record 561 | mizan teferi
# City not found. Skipping...
# Processing record 563 | mwaya
# Processing record 564 | kiunga
# Processing record 565 | nandura
# Processing record 566 | verkhnyaya inta
# Processing record 567 | udachnyy
# Processing record 568 | juegang
# Processing record 569 | bilma
# Processing record 570 | sheridan
# Processing record 571 | dawson creek
# Processing record 572 | srednekolymsk
# Processing record 573 | bodden town
# Processing record 574 | laguna
# Processing record 575 | ta khmau
# City not found. Skipping...
# Processing record 577 | atagay
# Processing record 578 | antofagasta
# Processing record 579 | ostroleka
# Processing record 580 | navirai
# Processing record 581 | ambilobe
# Processing record 582 | touros
# Processing record 583 | kysyl-syr
# Processing record 584 | mandalgovi
# Processing record 585 | balabac
# Processing record 586 | waitati
# Processing record 587 | luena
# Processing record 588 | jeremie
# Processing record 589 | broken hill
# Processing record 590 | orsha
# Processing record 591 | nishihara
# Processing record 592 | coquimbo
# Processing record 593 | kosh-agach
# City not found. Skipping...
# City not found. Skipping...
# Processing record 596 | kropotkin
# Processing record 597 | san policarpo
# Processing record 598 | altay
# Processing record 599 | milkovo
# Processing record 600 | nicoya
# Processing record 601 | pokhara
# Processing record 602 | dolores
# Processing record 603 | bonavista
# Processing record 604 | ngunguru
# Processing record 605 | ilo
# Processing record 606 | alice springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#export data to csv
cities_df.to_csv('../output_data/cities_df.csv')

#display number of values for each column in df
cities_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
#display the dataframe
cities_df.head()
# Out:
#            City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0      buraydah  26.33   43.98    102.2       15         62     13.869
# 1  punta arenas -53.15  -70.92     35.6       87         90    23.0404
# 2   port alfred -33.59   26.89   84.002       30          0    1.00662
# 3     ust-kulom  61.69   53.69   49.424       57         97    9.66356
# 4        atuona   -9.8 -139.03   78.908       73         28     14.898
#
#   Country        Date
# 0      SA  1593006537
# 1      CL  1593006537
# 2      ZA  1593006537
# 3      RU  1593006537
# 4      PF  1593006538

# %%
#inspect df and determine number of cities with over 100% humidity 
low_humidity_df = cities_df[cities_df.Humidity <= 100]
print(f'The number of cities with over 100% humidity is {len(cities_df) - len(low_humidity_df)}.')
# Out:
# The number of cities with over 100% humidity is 0.

# %%
#  Get the indices of cities that have humidity over 100%.
over_100_indexes = cities_df[cities_df.Humidity > 100].index
over_100_indexes
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data= cities_df
for x in over_100_indexes:
    clean_city_data = cities_df.drop([x])

clean_city_data.head()
# Out:
#            City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0      buraydah  26.33   43.98    102.2       15         62     13.869
# 1  punta arenas -53.15  -70.92     35.6       87         90    23.0404
# 2   port alfred -33.59   26.89   84.002       30          0    1.00662
# 3     ust-kulom  61.69   53.69   49.424       57         97    9.66356
# 4        atuona   -9.8 -139.03   78.908       73         28     14.898
#
#   Country        Date
# 0      SA  1593006537
# 1      CL  1593006537
# 2      ZA  1593006537
# 3      RU  1593006537
# 4      PF  1593006538

# %%
# Extract relevant fields from the data frame
lat = clean_city_data.Lat
max_temp = clean_city_data["Max Temp"]
humid = clean_city_data.Humidity
cloud = clean_city_data.Cloudiness
wind = clean_city_data['Wind Speed']

# Export the City_Data into a csv
clean_city_data.to_csv('../output_data/clean_city_data.csv')

# %%
#Latitude vs Temperature Plot

#save today's date in the today variable
today = pd.to_datetime('today').strftime("%m/%d/%y")
fig = plt.figure(figsize = (10,5))

#calling scatter plot
plt.scatter(lat, max_temp, edgecolors = "black")
plt.title(f'City Latitude vs Max Temperature ({today})')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

#saving figure in the output_data directory
fig.savefig('../output_data/lati_vs_temp.png')
plt.show()

# %%
#Latitude vs Humidity Plot

fig = plt.figure(figsize = (10,5))

#call scatter plot
plt.scatter(lat, humid, edgecolors = "black")
plt.title(f'City Latitude vs Humidity ({today})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

#saving figure to the output_data directory
fig.savefig('../output_data/lat_vs_humid.png')
plt.show()

# %%
#Latitude vs Cloudiness Plot

fig = plt.figure(figsize = (10,5))

#calling scatter plot
plt.scatter(lat, max_temp, edgecolors = "black")
plt.title(f'City Latitude vs Cloudiness ({today})')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

#saving file to the output_data directory
fig.savefig('../output_data/lat_vs_cloudiness.png')
plt.show()

# %%
#Latitude vs Wind Speed Plot

fig = plt.figure(figsize = (10,5))

#calling scatter plot
plt.scatter(lat, wind, edgecolors = "black")
plt.title(f'City Latitude vs Wind Speed ({today})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

#saving plot to the output_data directory
fig.savefig('../output_data/lat_vs_wind_speed.png')
plt.show()

# %%
# OPTIONAL: Create a function to create Linear Regression plots

#input is 2 lists and returns regress_values, the line equation of best fit, and the r correlation
def lin_regress(list_x, list_y):
    slope, int, r, p, st_err = st.linregress(list_x, list_y)
    regress_values = slope*list_x + int
    line_eq = f'y = {round(slope, 2)}x + {round(int,2)}'
    return regress_values, line_eq, r

# %%
# Create Northern and Southern Hemisphere DataFrames

north_hem = clean_city_data[clean_city_data["Lat"] >= 0]
south_hem = clean_city_data[clean_city_data["Lat"] < 0]

# %% [markdown]
# # All Northern Hemisphere Plots

# %%
#Preparing data for all the northern hemisphere plots

lat = north_hem.Lat.astype(float)
max_temp = north_hem["Max Temp"].astype(float)
humid = north_hem.Humidity.astype(float)
cloud = north_hem.Cloudiness.astype(float)
wind = north_hem['Wind Speed'].astype(float)

# %%
#Northern Hemisphere - Max Temp vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, max_temp)

fig = plt.figure(figsize = (10,5))

#calling the scatter plot
plt.scatter(lat, max_temp)
plt.title(f'City Latitude vs Max Temperature ({today})')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (10,40), fontsize = 15, color = "red" )

#saves the file to the output_data directory
fig.savefig('../output_data/north_lat_vs_temp.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.4514735117737576

# %%
#Northern Hemisphere - Humidity (%) vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, humid)

fig = plt.figure(figsize = (10,5))

#call scatter plot
plt.scatter(lat, humid)
plt.title(f'City Latitude vs Humidity ({today})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (50,10), fontsize = 15, color = "red" )

#saving figure to the output_data directory
fig.savefig('../output_data/north_lat_vs_humid.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.0014811579181860121

# %%
#Northern Hemisphere - Cloudiness (%) vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, cloud)

fig = plt.figure(figsize = (10,5))

#calling scatter plot
plt.scatter(lat, max_temp)
plt.title(f'City Latitude vs Cloudiness ({today})')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (60,100), fontsize = 15, color = "red" )

#saving file to the output_data directory
fig.savefig('../output_data/north_lat_vs_cloudiness.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.008952263202320261

# %%
#Northern Hemisphere - Wind Speed (mph) vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, wind)

fig = plt.figure(figsize = (10,5))

#calling scatter plot
plt.scatter(lat, wind)
plt.title(f'City Latitude vs Wind Speed ({today})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (50,25), fontsize = 15, color = "red" )

#saving plot to the output_data directory
fig.savefig('../output_data/north_lat_vs_wind_speed.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.004819915217075888

# %% [markdown]
# # All Southern Hemisphere Plots

# %%
#Preparing data for all the northern hemisphere plots

lat = south_hem.Lat.astype(float)
max_temp = south_hem["Max Temp"].astype(float)
humid = south_hem.Humidity.astype(float)
cloud = south_hem.Cloudiness.astype(float)
wind = south_hem['Wind Speed'].astype(float)

# %%
#Southern Hemisphere - Max Temp vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, max_temp)

fig = plt.figure(figsize = (10,5))

#calling the scatter plot
plt.scatter(lat, max_temp)
plt.title(f'City Latitude vs Max Temperature ({today})')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (-20,30), fontsize = 15, color = "red" )

#saves the file to the output_data directory
fig.savefig('../output_data/south_lat_vs_temp.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.5782351253355219

# %%
#Southern Hemisphere - Humidity (%) vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, humid)

fig = plt.figure(figsize = (10,5))

#call scatter plot
plt.scatter(lat, humid)
plt.title(f'City Latitude vs Humidity ({today})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (-50,40), fontsize = 15, color = "red" )

#saving figure to the output_data directory
fig.savefig('../output_data/south_lat_vs_humid.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.01785922252061943

# %%
#Southern Hemisphere - Cloudiness (%) vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, cloud)

fig = plt.figure(figsize = (10,5))

#calling scatter plot
plt.scatter(lat, cloud)
plt.title(f'City Latitude vs Cloudiness ({today})')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (-50,30), fontsize = 15, color = "red" )

#saving file to the output_data directory
fig.savefig('../output_data/south_lat_vs_cloudiness.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.055252687588183635

# %%
#Southern Hemisphere - Wind Speed (mph) vs Latitude Linear Regression

#calling the linear regression function and saving the 3 outputs(regress_values, line_eq, and r) to the regress variable
regress = lin_regress(lat, wind)

fig = plt.figure(figsize = (10,5))

#calling scatter plot
plt.scatter(lat, wind)
plt.title(f'City Latitude vs Wind Speed ({today})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

#plots the linear regression line
plt.plot(lat, regress[0], color = "red")
#adds the linear regression equation to the plot
plt.annotate(regress[1], (-50,20), fontsize = 15, color = "red" )

#saving plot to the output_data directory
fig.savefig('../output_data/south_lat_vs_wind_speed.png')
plt.show()

#prints the r-squared value
print(f'The r-squared is: {pow(regress[2], 2)}')
# Out:
# The r-squared is: 0.004507825934181055
